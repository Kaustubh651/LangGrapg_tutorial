# %%
from langgraph.graph import StateGraph ,START,END
from typing import TypedDict

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.environ["HF_TOKEN"],
)

try:
    resp = client.chat.completions.create(
        model="Qwen/Qwen3-8B",
        messages=[{"role": "user", "content": "hello"}],
    )
    print("Status: success")
    print(resp.choices[0].message.content)
except Exception as e:
    print(type(e).__name__)
    print(e)
# Out:
# Status: success
#
#
# Hello! 😊 How can I assist you today? Feel free to ask any questions or share what you need help with!

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)

response = client.chat.completions.create(
    model="qwen3:4b",
    messages=[
        {
            "role": "system",
            "content": "You are a helpful AI assistant."
        },
        {
            "role": "user",
            "content": "Explain LangGraph in simple terms."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Here's a simple explanation of **LangGraph** — no jargon, just plain English:
#
# ---
#
# ### 🧠 Think of it like this:
# **LangGraph is a tool for building "smart, memory-friendly conversations" with AI.**
#
# ---
#
# ### 🔍 Why do we need it? (The problem)
# Imagine you're having a chat with a friend who *always forgets* what happened earlier. Like:
# - You say: *"I need to pick up groceries."*
# - They reply: *"Okay, but do you want to buy ice cream too?"* (They forgot your first message!)
# - You say: *"I only want groceries."*
# - They reply: *"Wait, did you say ice cream? I'm confused!"*
#
# This is the problem LangGraph solves 👉 **AI systems often forget context** when doing long tasks (like writing a story, answering questions, or building reports). Without help, they start over or get confused.
#
# ---
#
# ### ✅ How LangGraph helps (the simple fix)
# ...

# %%
## BELow is the code to run the Ollama server locally on your machine. You can start the server by executing the following command in your terminal:
## ollama serve in cmd  write the following command in your terminal: ollama run qwen3:4b

# %%
from typing import Literal
from pydantic import BaseModel, Field
from langchain_ollama import ChatOllama


class Response(BaseModel):
    intent: Literal["question", "coding", "general"]
    answer: str
    confidence: float = Field(ge=0, le=1)


llm = ChatOllama(
    model="qwen3:4b",
    temperature=0,
)

structured_llm = llm.with_structured_output(Response)

result = structured_llm.invoke(
    "Explain what a LangGraph StateGraph is."
)

print(result)
# Out:
# intent='general' answer="A **LangGraph StateGraph** is a specific type of **stateful workflow graph** in the **LangGraph** library (part of the LangChain ecosystem). It’s designed to model complex, sequential AI workflows where the system’s *state* evolves through a series of defined steps (nodes), with transitions between steps controlled by conditions or outputs. Here’s a concise breakdown:\n\n### 🔑 Key Concepts\n1. **State**\n   - A dictionary (`dict`) that holds the *current context* (e.g., user input, intermediate results, session data).\n   - Example: `{'user_input': 'Hello', 'validation_result': None}`\n\n2. **Nodes**\n   - Functions that process the state and *modify it* (e.g., validate input, generate responses).\n   - Each node can return a new state or trigger transitions.\n\n3. **Edges**\n   - Define *how* the state moves between nodes (e.g., `if validation_result is valid → next_node`).\n   - Edges can be conditional, deterministic, or event-driven.\n\n4. **Graph Structu
# ...

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="qwen3:4b",
    temperature=0,
)

response = llm.invoke("What is LangGraph in one sentence?")

print(response.content)
# Out:
# LangGraph is a **stateful workflow framework for LangChain that enables complex conversational AI applications by seamlessly managing context and state transitions across multi-step interactions**.
#
# *(One sentence, covers purpose, key feature (state), and use case without jargon overload)*
